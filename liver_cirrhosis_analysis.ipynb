# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset (make sure the Excel file is in the same folder or give full path)
df = pd.read_excel("HealthCareData.xlsx")

# Preview data
df.head()
# Rename the long target column to a simpler name (if not already renamed)
df.rename(columns={
    'Predicted Value(Out Come–Patient suffering from liver  cirrosis or not)': 'Target'
}, inplace=True)

# If column is already 1/NaN, convert NaN to 0
df['Target'] = df['Target'].fillna(0).astype(int)
df['Target'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 import seaborn as sns
#       6 # Load the dataset (make sure the Excel file is in the same folder or give full path)
# ----> 7 df = pd.read_excel("HealthCareData.xlsx")
#       9 # Preview data
#      10 df.head()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %%
df = pd.read_excel("/Users/your-username/Downloads/liver_data_cleaned.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_excel("/Users/your-username/Downloads/liver_data_cleaned.xlsx")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df = pd.read_csv("/Users/vasavi/Documents/liver_data_cleaned.csv")

# %%
# Preview the top 5 rows
print(df.head())

# Summary of columns and data types
print(df.info())

# Basic stats
print(df.describe())
# Out:
#    Age Gender  AlcoholConsumption  HepatitisB  HepatitisC  Diabetes  Obesity  \
# 0   45      M                   4           1           0         1        0
# 1   60      F                   0           0           0         0        1
# 2   30      M                   3           0           1         1        0
# 3   52      M                   5           1           0         1        1
# 4   47      F                   1           1           1         0        1
#
#    LDL  HDL   TG  TCH  Predicted
# 0  130   50  200  220          1
# 1  110   60  180  200          0
# 2  145   45  210  230          0
# 3  155   40  220  240          1
# 4  140   55  190  215          1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 10 non-null     int64
#  1   Gender              10 non-null     object
# ...

# %%
# Value counts for categorical columns
print(df['Gender'].value_counts())
print(df['Predicted'].value_counts())

# Mean, median, mode, std for numerical features
print(df.describe())

# Skewness and kurtosis
print(df.skew(numeric_only=True))
print(df.kurtosis(numeric_only=True))

# Correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
# Out:
# Gender
# M    5
# F    5
# Name: count, dtype: int64
# Predicted
# 1    5
# 0    5
# Name: count, dtype: int64
#              Age  AlcoholConsumption  HepatitisB  HepatitisC   Diabetes  \
# count  10.000000           10.000000   10.000000   10.000000  10.000000
# mean   47.100000            2.100000    0.500000    0.300000   0.600000
# std    11.855144            2.282786    0.527046    0.483046   0.516398
# min    30.000000            0.000000    0.000000    0.000000   0.000000
# 25%    39.500000            0.000000    0.000000    0.000000   0.000000
# 50%    46.000000            1.500000    0.500000    0.000000   1.000000
# 75%    56.500000            3.750000    1.000000    0.750000   1.000000
# max    66.000000            6.000000    1.000000    1.000000   1.000000
#
#          Obesity        LDL        HDL          TG        TCH  Predicted
# count  10.000000   10.00000  10.000000   10.000000   10.00000  10.000000
# ...

# %%
df.head()
# Out:
#    Age Gender  AlcoholConsumption  HepatitisB  HepatitisC  Diabetes  Obesity  \
# 0   45      M                   4           1           0         1        0
# 1   60      F                   0           0           0         0        1
# 2   30      M                   3           0           1         1        0
# 3   52      M                   5           1           0         1        1
# 4   47      F                   1           1           1         0        1
#
#    LDL  HDL   TG  TCH  Predicted
# 0  130   50  200  220          1
# 1  110   60  180  200          0
# 2  145   45  210  230          0
# 3  155   40  220  240          1
# 4  140   55  190  215          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 10 non-null     int64
#  1   Gender              10 non-null     object
#  2   AlcoholConsumption  10 non-null     int64
#  3   HepatitisB          10 non-null     int64
#  4   HepatitisC          10 non-null     int64
#  5   Diabetes            10 non-null     int64
#  6   Obesity             10 non-null     int64
#  7   LDL                 10 non-null     int64
#  8   HDL                 10 non-null     int64
#  9   TG                  10 non-null     int64
#  10  TCH                 10 non-null     int64
#  11  Predicted           10 non-null     int64
# dtypes: int64(11), object(1)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#              Age  AlcoholConsumption  HepatitisB  HepatitisC   Diabetes  \
# count  10.000000           10.000000   10.000000   10.000000  10.000000
# mean   47.100000            2.100000    0.500000    0.300000   0.600000
# std    11.855144            2.282786    0.527046    0.483046   0.516398
# min    30.000000            0.000000    0.000000    0.000000   0.000000
# 25%    39.500000            0.000000    0.000000    0.000000   0.000000
# 50%    46.000000            1.500000    0.500000    0.000000   1.000000
# 75%    56.500000            3.750000    1.000000    0.750000   1.000000
# max    66.000000            6.000000    1.000000    1.000000   1.000000
#
#          Obesity        LDL        HDL          TG        TCH  Predicted
# count  10.000000   10.00000  10.000000   10.000000   10.00000  10.000000
# mean    0.500000  137.00000  49.800000  198.500000  223.00000   0.500000
# std     0.527046   16.02082   9.612492   18.416478   16.02082   0.527046
# ...
